# %% [markdown]
# <div style="text-align: center; font-size:x-large;">기계학습 기말 레포트</div>
#
# <div style="text-align: center; font-size:large;">2024. 12</div>

# %% [markdown]
# ## **워싱턴 주 King County 지역의 주택 거래 데이터를 이용한 주택 가격 예측**
#
# &nbsp; 해당 분석은 **kaggle**의 **House Sales in King County, USA** 데이터셋<sup>[1](#dataset)</sup>을 사용하여 진행되었으며, 해당 데이터셋은 워싱턴 주에서 가장 인구가 많은 King County 지역에서 2014년 5월부터 2015년 5월까지 이뤄진 실제 주택 거래 정보를 가지고 있다.
#
# ![Wasington-King County](attachment:26aca51d-b0f2-4a42-905e-d3e46607f558.png)
#
# Washington주의 King County 지역. Washington D.C가 아님.
#
# <a name="dataset">1</a>: https://www.kaggle.com/datasets/harlfoxem/housesalesprediction
#
# <p align="center" style="color:gray">
#   <img style="margin:50px 0 10px 0" src="![제목 없음-1.png](attachment:230eb8a8-9e0a-4a9c-9e51-168c47f18347.png)" alt="factorio thumbnail" width=200 />
#   Washington주의 King County 지역. Washington D.C가 아님.
# </p>
