# %%
df = read.csv("~/ML2024/data/Data/College.csv")
model = lm(Grad.Rate~., df)
summary(model)
# Out:
# Call:
# lm(formula = Grad.Rate ~ ., data = df)
#
# Residuals:
# ALL 777 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (17 not defined because of singularities)
#                                                  Estimate Std. Error t value
# (Intercept)                                     6.000e+01        NaN     NaN
# XAdelphi University                            -4.000e+00        NaN     NaN
# XAdrian College                                -6.000e+00        NaN     NaN
# XAgnes Scott College                           -1.000e+00        NaN     NaN
# XAlaska Pacific University                     -4.500e+01        NaN     NaN
# XAlbertson College                             -5.000e+00        NaN     NaN
# XAlbertus Magnus College                        3.000e+00        NaN     NaN
# XAlbion College                                 1.300e+01        NaN     NaN
# XAlbright College                               2.000e+01        NaN     NaN
# ...

# %%
anova(model)
# Out:
# Warning message in anova.lm(model):
# “ANOVA F-tests on an essentially perfect fit are unreliable”
#           Df  Sum Sq   Mean Sq  F value Pr(>F)
# X         776 228977.2 295.0737 NaN     NaN
# Residuals   0      0.0      NaN  NA      NA
